# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Leer el archivo de Excel
# Nota: Online Retail II tiene dos pestañas (Year 2009-2010 y Year 2010-2011)
print("Leyendo el archivo Excel... (esto puede tardar un poco)")
df_1 = pd.read_excel('online_retail_II.xlsx', sheet_name='Year 2009-2010')
df_2 = pd.read_excel('online_retail_II.xlsx', sheet_name='Year 2010-2011')

# Combinar ambas pestañas en un solo DataFrame
df_total = pd.concat([df_1, df_2], ignore_index=True)

# 2. Configurar la conexión a PostgreSQL
# Reemplaza con tus credenciales: usuario, contraseña, host y nombre de tu BD
USER = 'postgres'
PASSWORD = '2305'
HOST = 'localhost'
PORT = '5432'
DB_NAME = 'datascience_db'

engine = create_engine(f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}')

# 3. Cargar los datos en PostgreSQL
print("Cargando datos en PostgreSQL...")
df_total.to_sql('online_retail', con=engine, if_exists='replace', index=False)
print("¡Carga completada con éxito!")

# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Reconectarte a la base de datos
USER = 'postgres' # O tu usuario correspondiente
PASSWORD = '2305'
HOST = 'localhost'
PORT = '5432'
DB_NAME = 'datascience_db'

engine = create_engine(f'postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}')

# 2. Hacer una consulta de conteo (COUNT)
# Esto le pide a PostgreSQL que cuente cuántas filas tiene la tabla
query_conteo = "SELECT COUNT(*) FROM online_retail;"
filas_totales = pd.read_sql(query_conteo, con=engine)

print("Número total de filas en la base de datos:")
print(filas_totales)

# 3. Traer una pequeña muestra para ver la estructura
query_muestra = "SELECT * FROM online_retail LIMIT 5;"
muestra_datos = pd.read_sql(query_muestra, con=engine)

print("\nMuestra de las primeras 5 filas:")
print(muestra_datos)
